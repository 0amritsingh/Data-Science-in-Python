# %%
import pandas as pd

# %%
df = pd.read_csv('practice_dataset_dirty.csv')
df
# Out:
#     ID             Name   Age  Gender                City  \
# 0    1     Allison Hill  58.0   Other  North Richardmouth
# 1    2      Noah Rhodes  25.0    Male      East Jamesside
# 2    3  Angie Henderson  19.0  Female         Taylorburgh
# 3    4    Daniel Wagner  35.0    Male          Stevenland
# 4    5  Cristian Santos  33.0    Male          Mortonside
# ..  ..              ...   ...     ...                 ...
# 58  59     Brent Jordan  22.0   Other   North Candacestad
# 59  60      John Daniel  20.0   Other         Samuelhaven
# 60   1     Allison Hill  58.0   Other  North Richardmouth
# 61   6              NaN  32.0    Male    North Deniseside
# 62  37     Sherri Baker  39.0  Female   North Matthewberg
#
#                            Email   Join_Date  Salary
# 0       mlam@williams-graham.net  2024-02-12  100644
# 1   ryan59@alvarado-martinez.com  2024-08-03   64438
# 2              snguyen@yahoo.com  2021-03-08  106622
# 3       robertbentley@adkins.biz  2024-05-28   86155
# ...

# %%
df.head()
# Out:
#    ID             Name   Age  Gender                City  \
# 0   1     Allison Hill  58.0   Other  North Richardmouth
# 1   2      Noah Rhodes  25.0    Male      East Jamesside
# 2   3  Angie Henderson  19.0  Female         Taylorburgh
# 3   4    Daniel Wagner  35.0    Male          Stevenland
# 4   5  Cristian Santos  33.0    Male          Mortonside
#
#                           Email   Join_Date  Salary
# 0      mlam@williams-graham.net  2024-02-12  100644
# 1  ryan59@alvarado-martinez.com  2024-08-03   64438
# 2             snguyen@yahoo.com  2021-03-08  106622
# 3      robertbentley@adkins.biz  2024-05-28   86155
# 4             justin69@pena.com  2023-05-15  106484

# %%
df.tail()
# Out:
#     ID          Name   Age  Gender                City  \
# 58  59  Brent Jordan  22.0   Other   North Candacestad
# 59  60   John Daniel  20.0   Other         Samuelhaven
# 60   1  Allison Hill  58.0   Other  North Richardmouth
# 61   6           NaN  32.0    Male    North Deniseside
# 62  37  Sherri Baker  39.0  Female   North Matthewberg
#
#                         Email   Join_Date  Salary
# 58      cassandra01@gmail.com  2024-08-24   30074
# 59      barbara27@pearson.org  2022-11-21  108504
# 60   mlam@williams-graham.net  2024-02-12  100644
# 61  donnacampbell@hotmail.com  2023-11-18   82350
# 62     mariahmiller@yahoo.com  2022-02-20   44621

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         63 non-null     int64
#  1   Name       58 non-null     object
#  2   Age        62 non-null     float64
#  3   Gender     61 non-null     object
#  4   City       62 non-null     object
#  5   Email      61 non-null     object
#  6   Join_Date  63 non-null     object
#  7   Salary     63 non-null     int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.1+ KB

# %%
df.describe()
# Out:
#               ID        Age         Salary
# count  63.000000  62.000000      63.000000
# mean   29.746032  37.016129   78278.317460
# std    17.721837  12.972217   26983.018305
# min     1.000000  18.000000   30074.000000
# 25%    14.500000  25.000000   51071.500000
# 50%    30.000000  35.000000   82350.000000
# 75%    44.500000  49.250000  100644.000000
# max    60.000000  59.000000  119353.000000

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Gender', 'City', 'Email', 'Join_Date', 'Salary'], dtype='object')

# %%
df.shape
# Out:
# (63, 8)

# %%
df['Name']
# Out:
# 0        Allison Hill
# 1         Noah Rhodes
# 2     Angie Henderson
# 3       Daniel Wagner
# 4     Cristian Santos
#            ...
# 58       Brent Jordan
# 59        John Daniel
# 60       Allison Hill
# 61                NaN
# 62       Sherri Baker
# Name: Name, Length: 63, dtype: object

# %%
df[['Age','Name']]
# Out:
#      Age             Name
# 0   58.0     Allison Hill
# 1   25.0      Noah Rhodes
# 2   19.0  Angie Henderson
# 3   35.0    Daniel Wagner
# 4   33.0  Cristian Santos
# ..   ...              ...
# 58  22.0     Brent Jordan
# 59  20.0      John Daniel
# 60  58.0     Allison Hill
# 61  32.0              NaN
# 62  39.0     Sherri Baker
#
# [63 rows x 2 columns]

# %%
df.loc[4, 'Age']
# Out:
# 33.0

# %%
df.iloc[4,2]
# Out:
# 33.0

# %%
df.loc[61:63, ['Age', 'Gender', 'City']]
# Out:
#      Age  Gender               City
# 61  32.0    Male   North Deniseside
# 62  39.0  Female  North Matthewberg

# %%
df.iloc[61:63+1, 2:4+1]
# Out:
#      Age  Gender               City
# 61  32.0    Male   North Deniseside
# 62  39.0  Female  North Matthewberg

# %%
df.at[62,'Name']
# Out:
# 'Sherri Baker'

# %%
df.iat[62,1]
# Out:
# 'Sherri Baker'

# %%
df.query('Age > 54 and Gender == "Male"')
# Out:
#     ID              Name   Age Gender          City  \
# 27  28    Stephanie Ross  55.0   Male     Davidstad
# 43  44  Anthony Humphrey  56.0   Male     Jasonbury
# 54  55     Shannon Jones  57.0   Male  Michaelhaven
#
#                            Email   Join_Date  Salary
# 27    elliottjeffery@hotmail.com  2024-05-03  102512
# 43    griffithleslie@herrera.com  2021-06-10   95612
# 54  keithcampbell@jones-hall.com  2021-05-16   79009

# %%
df.loc[:,['Name', 'Salary']].query('Salary >= 100000').dropna().drop_duplicates()
# Out:
#                  Name  Salary
# 0        Allison Hill  100644
# 2     Angie Henderson  106622
# 4     Cristian Santos  106484
# 17       Derek Zuniga  119192
# 19         Carla Gray  108172
# 23       Tommy Walter  108104
# 27     Stephanie Ross  102512
# 29  Anthony Rodriguez  119166
# 32    Tricia Valencia  100381
# 34     Debra Davidson  114012
# 47    Shane Henderson  111959
# 49        Eric Carney  113748
# 51       Danny Morgan  109818
# 56     Timothy Duncan  100697
# 59        John Daniel  108504

# %%
df.isnull()
# Out:
#        ID   Name    Age  Gender   City  Email  Join_Date  Salary
# 0   False  False  False   False  False  False      False   False
# 1   False  False  False   False  False  False      False   False
# 2   False  False  False   False  False  False      False   False
# 3   False  False  False   False  False  False      False   False
# 4   False  False  False   False  False  False      False   False
# ..    ...    ...    ...     ...    ...    ...        ...     ...
# 58  False  False  False   False  False  False      False   False
# 59  False  False  False   False  False  False      False   False
# 60  False  False  False   False  False  False      False   False
# 61  False   True  False   False  False  False      False   False
# 62  False  False  False   False  False  False      False   False
#
# [63 rows x 8 columns]

# %%
df.dropna()
# Out:
#     ID                  Name   Age  Gender                  City  \
# 0    1          Allison Hill  58.0   Other    North Richardmouth
# 1    2           Noah Rhodes  25.0    Male        East Jamesside
# 2    3       Angie Henderson  19.0  Female           Taylorburgh
# 3    4         Daniel Wagner  35.0    Male            Stevenland
# 4    5       Cristian Santos  33.0    Male            Mortonside
# 6    7       Abigail Shaffer  26.0  Female        North Sarabury
# 8    9       Gabrielle Davis  52.0  Female          Port Richard
# 9   10            Ryan Munoz  23.0   Other     East Nicholasfurt
# 10  11        Monica Herrera  55.0  Female             Saramouth
# 11  12          Jamie Arnold  45.0    Male            Rodneyside
# 12  13          Lisa Hensley  20.0  Female             Mooreport
# 13  14      Michele Williams  19.0  Female            North Beth
# 14  15          Dylan Miller  23.0    Male           Lake Leeton
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 58    False
# 59    False
# 60     True
# 61     True
# 62     True
# Length: 63, dtype: bool

# %%
df.drop_duplicates()
# Out:
#     ID                  Name   Age  Gender                  City  \
# 0    1          Allison Hill  58.0   Other    North Richardmouth
# 1    2           Noah Rhodes  25.0    Male        East Jamesside
# 2    3       Angie Henderson  19.0  Female           Taylorburgh
# 3    4         Daniel Wagner  35.0    Male            Stevenland
# 4    5       Cristian Santos  33.0    Male            Mortonside
# 5    6                   NaN  32.0    Male      North Deniseside
# 6    7       Abigail Shaffer  26.0  Female        North Sarabury
# 7    8            Gina Moore  24.0     NaN            South Todd
# 8    9       Gabrielle Davis  52.0  Female          Port Richard
# 9   10            Ryan Munoz  23.0   Other     East Nicholasfurt
# 10  11        Monica Herrera  55.0  Female             Saramouth
# 11  12          Jamie Arnold  45.0    Male            Rodneyside
# 12  13          Lisa Hensley  20.0  Female             Mooreport
# ...

# %%
df.bfill().iloc[56,:]
# Out:
# ID                                     57
# Name                       Timothy Duncan
# Age                                  54.0
# Gender                               Male
# City                          Sheilaville
# Email        brooke94@martinez-barker.biz
# Join_Date                      2021-05-28
# Salary                             100697
# Name: 56, dtype: object

# %%
ds = pd.read_csv('practice_dataset.csv')
ds
# Out:
#     ID              Name  Age  Gender                City  \
# 0    1      Allison Hill   58   Other  North Richardmouth
# 1    2       Noah Rhodes   25    Male      East Jamesside
# 2    3   Angie Henderson   19  Female         Taylorburgh
# 3    4     Daniel Wagner   35    Male          Stevenland
# 4    5   Cristian Santos   33    Male          Mortonside
# 5    6   Connie Lawrence   32    Male    North Deniseside
# 6    7   Abigail Shaffer   26  Female      North Sarabury
# 7    8        Gina Moore   24  Female          South Todd
# 8    9   Gabrielle Davis   52  Female        Port Richard
# 9   10        Ryan Munoz   23   Other   East Nicholasfurt
# 10  11    Monica Herrera   55  Female           Saramouth
# 11  12      Jamie Arnold   45    Male          Rodneyside
# 12  13      Lisa Hensley   20  Female           Mooreport
# 13  14  Michele Williams   19  Female          North Beth
# 14  15      Dylan Miller   23    Male         Lake Leeton
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         15 non-null     int64
#  1   Name       15 non-null     object
#  2   Age        15 non-null     int64
#  3   Gender     15 non-null     object
#  4   City       15 non-null     object
#  5   Email      15 non-null     object
#  6   Join_Date  15 non-null     object
#  7   Salary     15 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 1.1+ KB

# %%
ds['Salary']= ds['Salary'].astype('float')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         15 non-null     int64
#  1   Name       15 non-null     object
#  2   Age        15 non-null     int64
#  3   Gender     15 non-null     object
#  4   City       15 non-null     object
#  5   Email      15 non-null     object
#  6   Join_Date  15 non-null     object
#  7   Salary     15 non-null     float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.1+ KB

# %%
ds["Join_Date"] = pd.to_datetime(df['Join_Date']) # important

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         15 non-null     int64
#  1   Name       15 non-null     object
#  2   Age        15 non-null     int64
#  3   Gender     15 non-null     object
#  4   City       15 non-null     object
#  5   Email      15 non-null     object
#  6   Join_Date  15 non-null     datetime64[ns]
#  7   Salary     15 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 1.1+ KB

# %%
ds.dtypes # to check datatypes
# Out:
# ID                    int64
# Name                 object
# Age                   int64
# Gender               object
# City                 object
# Email                object
# Join_Date    datetime64[ns]
# Salary              float64
# dtype: object

# %%
ds.sort_values('Salary')
# Out:
#     ID              Name  Age  Gender                City  \
# 12  13      Lisa Hensley   20  Female           Mooreport
# 11  12      Jamie Arnold   45    Male          Rodneyside
# 13  14  Michele Williams   19  Female          North Beth
# 8    9   Gabrielle Davis   52  Female        Port Richard
# 14  15      Dylan Miller   23    Male         Lake Leeton
# 7    8        Gina Moore   24  Female          South Todd
# 1    2       Noah Rhodes   25    Male      East Jamesside
# 6    7   Abigail Shaffer   26  Female      North Sarabury
# 5    6   Connie Lawrence   32    Male    North Deniseside
# 3    4     Daniel Wagner   35    Male          Stevenland
# 10  11    Monica Herrera   55  Female           Saramouth
# 9   10        Ryan Munoz   23   Other   East Nicholasfurt
# 0    1      Allison Hill   58   Other  North Richardmouth
# 4    5   Cristian Santos   33    Male          Mortonside
# 2    3   Angie Henderson   19  Female         Taylorburgh
#
# ...

# %%
ds.sort_values(['Salary', 'Age'], ascending=False)
# Out:
#     ID              Name  Age  Gender                City  \
# 2    3   Angie Henderson   19  Female         Taylorburgh
# 4    5   Cristian Santos   33    Male          Mortonside
# 0    1      Allison Hill   58   Other  North Richardmouth
# 9   10        Ryan Munoz   23   Other   East Nicholasfurt
# 10  11    Monica Herrera   55  Female           Saramouth
# 3    4     Daniel Wagner   35    Male          Stevenland
# 5    6   Connie Lawrence   32    Male    North Deniseside
# 6    7   Abigail Shaffer   26  Female      North Sarabury
# 1    2       Noah Rhodes   25    Male      East Jamesside
# 7    8        Gina Moore   24  Female          South Todd
# 14  15      Dylan Miller   23    Male         Lake Leeton
# 8    9   Gabrielle Davis   52  Female        Port Richard
# 13  14  Michele Williams   19  Female          North Beth
# 11  12      Jamie Arnold   45    Male          Rodneyside
# 12  13      Lisa Hensley   20  Female           Mooreport
#
# ...

# %%
ds2 = ds.sort_values(['Salary', 'Age'], ascending=False).copy()

# %%
ds2.reset_index()
# Out:
#     index  ID              Name  Age  Gender                City  \
# 0       2   3   Angie Henderson   19  Female         Taylorburgh
# 1       4   5   Cristian Santos   33    Male          Mortonside
# 2       0   1      Allison Hill   58   Other  North Richardmouth
# 3       9  10        Ryan Munoz   23   Other   East Nicholasfurt
# 4      10  11    Monica Herrera   55  Female           Saramouth
# 5       3   4     Daniel Wagner   35    Male          Stevenland
# 6       5   6   Connie Lawrence   32    Male    North Deniseside
# 7       6   7   Abigail Shaffer   26  Female      North Sarabury
# 8       1   2       Noah Rhodes   25    Male      East Jamesside
# 9       7   8        Gina Moore   24  Female          South Todd
# 10     14  15      Dylan Miller   23    Male         Lake Leeton
# 11      8   9   Gabrielle Davis   52  Female        Port Richard
# 12     13  14  Michele Williams   19  Female          North Beth
# ...

# %%
ds2.reset_index(drop=True, inplace=True) # drop = True will remove the backup index column after resetting the index

# %%
ds2 # inplace = True will make changes permanente, it will not show a preview of changes
# Out:
#     ID              Name  Age  Gender                City  \
# 0    3   Angie Henderson   19  Female         Taylorburgh
# 1    5   Cristian Santos   33    Male          Mortonside
# 2    1      Allison Hill   58   Other  North Richardmouth
# 3   10        Ryan Munoz   23   Other   East Nicholasfurt
# 4   11    Monica Herrera   55  Female           Saramouth
# 5    4     Daniel Wagner   35    Male          Stevenland
# 6    6   Connie Lawrence   32    Male    North Deniseside
# 7    7   Abigail Shaffer   26  Female      North Sarabury
# 8    2       Noah Rhodes   25    Male      East Jamesside
# 9    8        Gina Moore   24  Female          South Todd
# 10  15      Dylan Miller   23    Male         Lake Leeton
# 11   9   Gabrielle Davis   52  Female        Port Richard
# 12  14  Michele Williams   19  Female          North Beth
# 13  12      Jamie Arnold   45    Male          Rodneyside
# 14  13      Lisa Hensley   20  Female           Mooreport
#
# ...

# %%
ds2['Rank'] = ds2['Salary'].rank()
ds2
# Out:
#     ID              Name  Age  Gender                City  \
# 0    3   Angie Henderson   19  Female         Taylorburgh
# 1    5   Cristian Santos   33    Male          Mortonside
# 2    1      Allison Hill   58   Other  North Richardmouth
# 3   10        Ryan Munoz   23   Other   East Nicholasfurt
# 4   11    Monica Herrera   55  Female           Saramouth
# 5    4     Daniel Wagner   35    Male          Stevenland
# 6    6   Connie Lawrence   32    Male    North Deniseside
# 7    7   Abigail Shaffer   26  Female      North Sarabury
# 8    2       Noah Rhodes   25    Male      East Jamesside
# 9    8        Gina Moore   24  Female          South Todd
# 10  15      Dylan Miller   23    Male         Lake Leeton
# 11   9   Gabrielle Davis   52  Female        Port Richard
# 12  14  Michele Williams   19  Female          North Beth
# 13  12      Jamie Arnold   45    Male          Rodneyside
# 14  13      Lisa Hensley   20  Female           Mooreport
#
# ...

# %%
# lets see ranking of age
ds2['Rank'] = ds2['Age'].rank()
ds2
# Out:
#     ID              Name  Age  Gender                City  \
# 0    3   Angie Henderson   19  Female         Taylorburgh
# 1    5   Cristian Santos   33    Male          Mortonside
# 2    1      Allison Hill   58   Other  North Richardmouth
# 3   10        Ryan Munoz   23   Other   East Nicholasfurt
# 4   11    Monica Herrera   55  Female           Saramouth
# 5    4     Daniel Wagner   35    Male          Stevenland
# 6    6   Connie Lawrence   32    Male    North Deniseside
# 7    7   Abigail Shaffer   26  Female      North Sarabury
# 8    2       Noah Rhodes   25    Male      East Jamesside
# 9    8        Gina Moore   24  Female          South Todd
# 10  15      Dylan Miller   23    Male         Lake Leeton
# 11   9   Gabrielle Davis   52  Female        Port Richard
# 12  14  Michele Williams   19  Female          North Beth
# 13  12      Jamie Arnold   45    Male          Rodneyside
# 14  13      Lisa Hensley   20  Female           Mooreport
#
# ...

# %%
# as you can see there are 1.5 and 4.5 valuse can be seen becasue on same value ranking will we done on average
# to avoide this you need to do this
ds2['Rank'] = ds2['Age'].rank(method='dense')
ds2
# Out:
#     ID              Name  Age  Gender                City  \
# 0    3   Angie Henderson   19  Female         Taylorburgh
# 1    5   Cristian Santos   33    Male          Mortonside
# 2    1      Allison Hill   58   Other  North Richardmouth
# 3   10        Ryan Munoz   23   Other   East Nicholasfurt
# 4   11    Monica Herrera   55  Female           Saramouth
# 5    4     Daniel Wagner   35    Male          Stevenland
# 6    6   Connie Lawrence   32    Male    North Deniseside
# 7    7   Abigail Shaffer   26  Female      North Sarabury
# 8    2       Noah Rhodes   25    Male      East Jamesside
# 9    8        Gina Moore   24  Female          South Todd
# 10  15      Dylan Miller   23    Male         Lake Leeton
# 11   9   Gabrielle Davis   52  Female        Port Richard
# 12  14  Michele Williams   19  Female          North Beth
# 13  12      Jamie Arnold   45    Male          Rodneyside
# 14  13      Lisa Hensley   20  Female           Mooreport
#
# ...

# %%
# renaming columns
ds2.rename(columns={'Gender':'Sex'}, inplace=True)
ds2
# Out:
#     ID              Name  Age     Sex                City  \
# 0    3   Angie Henderson   19  Female         Taylorburgh
# 1    5   Cristian Santos   33    Male          Mortonside
# 2    1      Allison Hill   58   Other  North Richardmouth
# 3   10        Ryan Munoz   23   Other   East Nicholasfurt
# 4   11    Monica Herrera   55  Female           Saramouth
# 5    4     Daniel Wagner   35    Male          Stevenland
# 6    6   Connie Lawrence   32    Male    North Deniseside
# 7    7   Abigail Shaffer   26  Female      North Sarabury
# 8    2       Noah Rhodes   25    Male      East Jamesside
# 9    8        Gina Moore   24  Female          South Todd
# 10  15      Dylan Miller   23    Male         Lake Leeton
# 11   9   Gabrielle Davis   52  Female        Port Richard
# 12  14  Michele Williams   19  Female          North Beth
# 13  12      Jamie Arnold   45    Male          Rodneyside
# 14  13      Lisa Hensley   20  Female           Mooreport
#
# ...

# %%
# renaming indeces
inds = {}
for i in range(ds2.Name.count()):
    inds[i] = f'Row {i+1}'
ds2.rename(index=inds, inplace=True)
ds2
# Out:
#         ID              Name  Age     Sex                City  \
# Row 1    3   Angie Henderson   19  Female         Taylorburgh
# Row 2    5   Cristian Santos   33    Male          Mortonside
# Row 3    1      Allison Hill   58   Other  North Richardmouth
# Row 4   10        Ryan Munoz   23   Other   East Nicholasfurt
# Row 5   11    Monica Herrera   55  Female           Saramouth
# Row 6    4     Daniel Wagner   35    Male          Stevenland
# Row 7    6   Connie Lawrence   32    Male    North Deniseside
# Row 8    7   Abigail Shaffer   26  Female      North Sarabury
# Row 9    2       Noah Rhodes   25    Male      East Jamesside
# Row 10   8        Gina Moore   24  Female          South Todd
# Row 11  15      Dylan Miller   23    Male         Lake Leeton
# Row 12   9   Gabrielle Davis   52  Female        Port Richard
# Row 13  14  Michele Williams   19  Female          North Beth
# Row 14  12      Jamie Arnold   45    Male          Rodneyside
# ...

# %%
# order of columns (also you can remove columns by doing this)
ds2 = ds2[['Name', 'Sex', 'Age', 'Join_Date', 'Email', 'Salary', 'City']]
ds2
# Out:
#                     Name     Sex  Age  Join_Date  \
# Row 1    Angie Henderson  Female   19 2021-03-08
# Row 2    Cristian Santos    Male   33 2023-05-15
# Row 3       Allison Hill   Other   58 2024-02-12
# Row 4         Ryan Munoz   Other   23 2021-10-10
# Row 5     Monica Herrera  Female   55 2023-03-19
# Row 6      Daniel Wagner    Male   35 2024-05-28
# Row 7    Connie Lawrence    Male   32 2023-11-18
# Row 8    Abigail Shaffer  Female   26 2023-03-30
# Row 9        Noah Rhodes    Male   25 2024-08-03
# Row 10        Gina Moore  Female   24 2023-02-20
# Row 11      Dylan Miller    Male   23 2023-10-25
# Row 12   Gabrielle Davis  Female   52 2021-04-18
# Row 13  Michele Williams  Female   19 2022-11-10
# Row 14      Jamie Arnold    Male   45 2023-11-28
# Row 15      Lisa Hensley  Female   20 2024-08-15
#
#                                Email    Salary                City
# Row 1              snguyen@yahoo.com  106622.0         Taylorburgh
# ...

# %%
data = {
    'Name':['Amrit', 'Manav', 'Vivek'],
    'Maths':[89,33,78],
    'Physics':[78,93,29],
    'Chemistry':[48,39,23]
}
marks = pd.DataFrame(data)
marks
# Out:
#     Name  Maths  Physics  Chemistry
# 0  Amrit     89       78         48
# 1  Manav     33       93         39
# 2  Vivek     78       29         23

# %%
melted_marks = marks.melt(id_vars='Name', value_vars=['Maths', 'Physics', 'Chemistry'], var_name='Subjects', value_name='Marks')
melted_marks
# Out:
#     Name   Subjects  Marks
# 0  Amrit      Maths     89
# 1  Manav      Maths     33
# 2  Vivek      Maths     78
# 3  Amrit    Physics     78
# 4  Manav    Physics     93
# 5  Vivek    Physics     29
# 6  Amrit  Chemistry     48
# 7  Manav  Chemistry     39
# 8  Vivek  Chemistry     23

# %%
pivoted_marks = melted_marks.pivot(index='Name', columns='Subjects', values='Marks')
pivoted_marks
# Out:
# Subjects  Chemistry  Maths  Physics
# Name
# Amrit            48     89       78
# Manav            39     33       93
# Vivek            23     78       29

# %%
# but pivot can throw errors if the vlaues are duplicate like
data2 = {
    'Name':['Amrit', 'Amrit', 'Manav', 'Manav'],
    'Stream':['PCM','PCM','PCM','PCM'],
    'Percentage':[80,70,90,58]
}
marks2 = pd.DataFrame(data2)
marks2
# Out:
#     Name Stream  Percentage
# 0  Amrit    PCM          80
# 1  Amrit    PCM          70
# 2  Manav    PCM          90
# 3  Manav    PCM          58

# %%
marks2.pivot(index='Name', columns='Stream', values='Percentage')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[328], line 1
# ----> 1 marks2.pivot(index='Name', columns='Stream', values='Percentage')
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# -> 9339     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...

# %%
# as you can see (read the last line for the error), so to prevent this we need to use pivot_table.
marks2.pivot_table(index='Name', columns='Stream', values='Percentage', aggfunc='min')
# its requares a aggregate function, it can be anything like mean, count, min, max, etc.
# Out:
# Stream  PCM
# Name
# Amrit    70
# Manav    58

# %%
corporate = pd.DataFrame({
    "Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
    "Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
    "Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
    "Salary": [85, 90, 78, 85, 92, 88, 75, 80],
    "Age": [23, 25, 30, 22, 28, 26, 21, 27],
    "JoinDate": pd.to_datetime([
        "2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
        "2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
    ])
})  

corporate
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
corporate.groupby(['Team'])['Salary'].agg('mean')
# Out:
# Team
# A    87.5
# B    81.5
# C    90.0
# D    77.5
# Name: Salary, dtype: float64

# %%
corporate.groupby(['Department', 'Gender'])['Salary'].agg(['min', 'mean', 'max'])
# Out:
#                    min  mean  max
# Department Gender
# HR         F        90  90.0   90
#            M        85  85.0   85
# IT         F        85  85.0   85
#            M        78  78.0   78
# Marketing  F        88  88.0   88
#            M        92  92.0   92
# Sales      F        80  80.0   80
#            M        75  75.0   75

# %%
corporate['Ava_Salary'] = corporate.groupby('Department')['Salary'].transform('mean')
corporate
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Ava_Salary
# 0         HR    A      M      85   23 2020-01-10        87.5
# 1         HR    A      F      90   25 2020-02-15        87.5
# 2         IT    B      M      78   30 2021-03-20        81.5
# 3         IT    B      F      85   22 2021-04-10        81.5
# 4  Marketing    C      M      92   28 2020-05-30        90.0
# 5  Marketing    C      F      88   26 2020-06-25        90.0
# 6      Sales    D      M      75   21 2021-07-15        77.5
# 7      Sales    D      F      80   27 2021-08-01        77.5

# %%
# data frame merging and joing we'll do later but now I'm that much capable that I can start making a project using pandas and numpy as well.
